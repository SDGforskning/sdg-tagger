# %% [markdown]
# # Run automatic testing
# ### This script runs all automatic tests for the repository. All test must pass before you push your changes to the repo!
#
# If you prefer to you can also trigger these commands from your terminal. Just copy the command without the '!' and run it.

# %%
#Installs all python packages listed in the requirements file. You can skip this step if you have already done this in your envirionment.
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pytest==8.2.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (8.2.2)
# Requirement already satisfied: iniconfig in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest==8.2.2->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest==8.2.2->-r requirements.txt (line 1)) (24.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest==8.2.2->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: pluggy<2.0,>=1.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest==8.2.2->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: tomli>=1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pytest==8.2.2->-r requirements.txt (line 1)) (2.0.1)

# %%
#This command triggers all the automatic tests. Check the output after running this to ensure that all the tests passed.
# !pytest -v
# Out:
# ========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= test session starts ==========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# platform linux -- Python 3.10.11, pytest-8.2.2, pluggy-1.5.0 -- /anaconda/envs/azureml_py38/bin/python
# cachedir: .pytest_cache
# rootdir: /mnt/batch/tasks/shared/LS_root/mounts/clusters/mog4/code/Users/mog/sdg-tagger
# configfile: pyproject.toml
# testpaths: tests
# plugins: anyio-4.6.0, mock-3.15.1
# collected 29 items
#
# tests/test_json_format.py::test_json_format[sdg1.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [  3%]
# tests/test_json_format.py::test_json_format[sdg2.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [  6%]
# tests/test_json_format.py::test_json_format[sdg3.json] SKIPPED (The file sdg3.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [ 10%]
# tests/test_json_format.py::test_json_format[sdg4.json] SKIPPED (The file sdg4.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [ 13%]
# tests/test_json_format.py::test_json_format[sdg5.json] SKIPPED (The file sdg5.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [ 17%]
# tests/test_json_format.py::test_json_format[sdg6.json] SKIPPED (The file sdg6.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [ 20%]
# tests/test_json_format.py::test_json_format[sdg7.json] SKIPPED (The file sdg7.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [ 24%]
# tests/test_json_format.py::test_json_format[sdg8.json] SKIPPED (The file sdg8.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [ 27%]
# tests/test_json_format.py::test_json_format[sdg9.json] SKIPPED (The file sdg9.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [ 31%]
# tests/test_json_format.py::test_json_format[sdg10.json] SKIPPED (The file sdg10.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [ 34%]
# tests/test_json_format.py::test_json_format[sdg11.json] SKIPPED (The file sdg11.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [ 37%]
# tests/test_json_format.py::test_json_format[sdg12.json] SKIPPED (The file sdg12.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [ 41%]
# tests/test_json_format.py::test_json_format[sdg13.json] SKIPPED (The file sdg13.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [ 44%]
# tests/test_json_format.py::test_json_format[sdg14.json] SKIPPED (The file sdg14.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [ 48%]
# tests/test_json_format.py::test_json_format[sdg15.json] SKIPPED (The file sdg15.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [ 51%]
# tests/test_json_format.py::test_json_format[sdg16.json] SKIPPED (The file sdg16.json does not exist.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [ 55%]
# tests/test_json_format.py::test_json_format[sdg1_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [ 58%]
# tests/test_json_format.py::test_json_format[sdg2_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [ 62%]
# tests/test_json_format.py::test_json_format[sdg3_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [ 65%]
# tests/test_json_format.py::test_json_format[sdg4_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [ 68%]
# tests/test_json_format.py::test_json_format[sdg7_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [ 72%]
# tests/test_json_format.py::test_json_format[sdg11_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [ 75%]
# tests/test_json_format.py::test_json_format[sdg12_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [ 79%]
# tests/test_json_format.py::test_json_format[sdg13_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [ 82%]
# tests/test_json_format.py::test_json_format[sdg14_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [ 86%]
# tests/test_json_format.py::test_json_format[sdg15_template.json] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [ 89%]
# tests/test_string_conversion.py::test_format_logic_rules_all_true[([termlist1_ba] | [termlist1_ba_trunc]) & [termlist1_bb] | ([termlist1_bc] & ([termlist1_bd] | [termlist1_bd_trunc]))-(True or True) and True or (True and (True or True))] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [ 93%]
# tests/test_string_conversion.py::test_format_logic_rules_all_false[([termlist1_ba] | [termlist1_ba_trunc]) & [termlist1_bb] | ([termlist1_bc] & ([termlist1_bd] | [termlist1_bd_trunc]))-(False or False) and False or (False and (False or False))] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [ 96%]
# tests/test_string_conversion.py::test_format_logic_rules_combined_true_false[([termlist1_ba] | [termlist1_ba_trunc]) & [termlist1_bb] | ([termlist1_bc] & ([termlist1_bd] | [termlist1_bd_trunc]))-(True or False) and True or (True and (False or True))] PASSED                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [100%]
#
# ==================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== 15 passed, 14 skipped in 1.58s ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
